# %% [markdown]
# # Практическая работа №2: Классические методы математической статистики
# Выполнил студент гр.1375 Нарыжный Даниил. Вариант №18

# %% [markdown]
# ## Цель работы
# Научиться применять методы математической статистики для решения задач статистического анализа; сформировать навыки реализации методов с помощью прикладных программных пакетов.

# %% [markdown]
# ## Основные теоретические положения
#
# $Мат.ожидание\\Ex=\frac{{\displaystyle\sum_{i=1}^n}x_i}n\\Дисперсия:\\\operatorname{𝐷}X=E\left(X-E\left(X\right)\right)^2\\СКО:\\s=\left(\operatorname{𝐷}X\right)^\frac12\\Ассиметрия:\\\widehat{Skew}\left(x\right)=\frac{{\displaystyle\frac1n}{\displaystyle\sum_{i=1}^n}\left(x_i-\overline x\right)^3}{s^3}\\Эксцесс:\\\widehat{Kurt}\left(x\right)=\frac{\displaystyle\frac1n\sum_{i=1}^n\left(x_i-\overline x\right)^4}{s^4}-3\\вероятность\;попадания:\\P\left(x\in\left[a,b\right]\right)=F\left(b\right)-F\left(a\right)\\Плотность\;распределения\;Пуассона:\\P_\theta\left(x\right)=\frac{\lambda^x}{x!}e^{-\lambda}\\Плотность\;нормального\;распределения:\\P_\theta\left(x\right)=\frac1{\sigma\sqrt{2\pi}}exp\left(-\frac{\left(x-\mu\right)^2}{2\sigma^2}\right)$
#
# $Статистика\;критерия\;Колмогорова:\\D_n=sup_{x\in\mathbb{R}}\left|F_n\left(x\right)-F_0\left(x\right)\right|\\Теорема\;Колмогорова:\\\sqrt nD_n\Rightarrow\;K\\P_{F_0}\left(\sqrt nD_n<x\right)\rightarrow K\left(x\right),\mathbb{R}\left(x\right)\\где\;K\;-\;распределение\;Колмогорова\\Гипотеза\;отклоняется,\;если\;\\D_n>x\\Принимается,\;если\;\\D_n<x\\Статистика\;отношения\;правдоподобия:\\LR\left(x\right)=\frac{L\left(x,\theta_1\right)}{L\left(x,\theta_0\right)}=\left(\frac{\theta_1\left(1-\theta_0\right)}{\theta_0\left(1-\theta_1\right)}\right)^{\sum_{i=1}^nx_i},\\где\;L\left(x,\theta_1\right)\;и\;L\left(x,\theta_0\right)\;-\;функции\;правдоподобия\\Запись\;критерия\;Колмогорова\;и\;запись\;в\;терминах\;\overline X:\\Ф\left(x\right)=\left\{\begin{array}{l}1,\;LR\left(x\right)>C\\p,\;LR\left(x\right)=C\\0,\;LR\left(x\right)<C\end{array}\right.\\Ф\left(x\right)=\left\{\begin{array}{l}1,\;\overline X<C^\ast\\p,\;\overline X=C^\ast\\0,\;\overline X>C^\ast\end{array}\right.\\LR\left(X\right)>C\Leftrightarrow\overline X<C^\ast\\LR\left(X\right)<C\Leftrightarrow\overline X>C^\ast$
#
# $ОМП:\\Оценка\;\widehat\theta\left(x\right),\;максимизирующая\;функцию\;правдоподобия\;L\left(x;\theta\right)\;по\;\theta\;при\;каждом\\фиксированном\;Х:\\L\left(X;\widehat\theta\left(X\right)\right)\geq L\left(X;\widetilde\theta\left(X\right)\right),\;\forall X\in\mathfrak X,\;\forall\widetilde\theta\left(X\right)\\называется\;оценкой\;максимального\;правдоподобия\\\\Оценка\;является\;несмещенной,\;если\;выполняется\;следующее\;условие:\\E\left(\widehat\theta\left(x\right)\right)=\theta\\\\ОММ:\\Если\;существует\;единственное\;решение\;\widetilde\theta\left(x\right)\;системы\;уравнений:\\\widehat{\mu_k}\left(\widetilde\theta\right)=\mu_k\left(\widetilde\theta\right),\;k=1,2..d\\где\;\widehat{\mu_k}\left(\widetilde\theta\right)=\frac1n\sum_{i=1}^nx_i^k\;-\;выборочный\;момент\;k-ого\;порядка,\;то\;\widetilde\theta\left(x\right)\\называется\;оценкой\;по\;методу\;моментов$
# $Смещением\;называется\;величина:\\bias\widehat{{}_\theta}\left(\theta\right)=E_{{}_\theta}\widehat{{}_\theta}\left(x\right)-\theta$
#
# $Доверительный\;интервал:\\Статистика\;\widehat\theta:\mathfrak X\rightarrow\mathbb{R}^2,\;удовлетворяющая\;условию\;\\{\mathbb{P}}_\theta\left(\left[Т_1\left(\overrightarrow x\right),Т_2\left(\overrightarrow x\right)\right]\ni\theta\right)\geq1-\alpha\\называется\;доверительным\;интервалом\;параметра\;\theta\;уровня\;доверия\;1-\alpha$
#
# $Асимптотический\;доверительный\;интервал:\\На\;базе\;ОМП\\\left[\widehat\theta-\frac{x_\alpha}{\sqrt{nl\left(\widehat\theta\right)}};\widehat\theta+\frac{x_\alpha}{\sqrt{nl\left(\widehat\theta\right)}}\right]\ni\theta\\На\;базе\;асимптотически\;нормальной\;оценки\;параметра\;\widehat\theta:\\\left[\widehat\theta\left(\overrightarrow x\right)-\frac{x_\alpha\times\sigma\left(\widehat\theta\left(\overrightarrow x\right)\right)}{\sqrt n};\widehat\theta\left(\overrightarrow x\right)+\frac{x_\alpha\times\sigma\left(\widehat\theta\left(\overrightarrow x\right)\right)}{\sqrt n}\right]\ni\theta$
# $Статистической\;гипотезой\;называется\;утверждение\;о\;параметре\;вида:\\H:\theta\in\Theta^\ast\subseteq\;\Theta\\Одноточечная\;гипотеза\;H_0:\theta=\theta^\ast,\;определяющая\;точное\;значение\;параметра,\;\\называется\;простой.\\Основная\;гипотеза:\\H_0∶\theta\;\in\;\Theta_0\\Альтернативная\;гипотеза:\\H_A:\theta\in\;\Theta_A:\Theta_0\cap\Theta_A==\;\varnothing\\Статистика\;критерия:\\X^2=\sum_{i=1}^r\frac{\left(n_i-nP_i\right)^2}{nP_i}$

# %% [markdown]
# ## Постановка задачи
# Для полученных в результате эксперимента наборов данных выполнить статистическую обработку. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### Часть 1
# #### a)Построить вариационный ряд, эмпирическую функцию распределения и гистограмму частот

# %%
import matplotlib.pyplot as plt
import numpy as np
def graphic_builder(x_values:list,y_values:list,title:str,x_title:str,y_title:str)->None:
    """
    функция для построения графика эмпирической функции
    """
    
    plt.step(x_values,y_values,where="post",color="r")
    plt.xlabel(x_title)
    plt.ylabel(y_title)
    plt.title(title)
    plt.show()

def variation(data:list)->list:
    """
    Построение вариационного ряда
    """
    sorted_data:list =sorted(data)
    print(f"Вариационный ряд: \n{sorted_data}\n")
    return sorted_data

def empirical_function(sorted_data:list,unique_digits:list)->None:
    """
    Построение эмпирической функции
    """
   
    #подсчет общего количества чисел и количества каждого числа из вариационного ряда
    overall_count:int = len(sorted_data)
    digits_dict: dict = {digit: sum(1 for i in data if i==digit) for digit in unique_digits}
    
    #Частота 
    frequency:dict = {digit: digit_count/overall_count for digit,digit_count in digits_dict.items()}
    print(f"Общее количество чисел: {overall_count}\n")
    for key, value in digits_dict.items():
        print(f"Число {key} Количество {value}")
    print("\n")
    for key, value in frequency.items():
        print(f"Число {key} Частота {value}")

    #Значение Х, значение У
    x_values:list = list(frequency.keys())
    y_values:list = [sum(frequency[digit] for digit in x_values if digit <= x) for x in x_values]
    title:str = "Эмпирическая функция распределения"
    x_title:str = "Значения"
    y_title:str = "Относительная частота"
    print(f"\nЗначения X {x_values}\n")
    print(f"\nЗначения Y {y_values}\n")
    x_values.insert(0, min(sorted_data))
    y_values.insert(0, 0)
    
    #Построение графика эмпирической функции
    graphic_builder(x_values,y_values,title,x_title,y_title)
    

def histogram(data:list,unique_digits:list)->None:
    """
    Построение гистограммы
    """
    plt.hist(sorted_data,bins=(len(unique_digits)), color="white", edgecolor="red")
    plt.title("Гистограмма")
    plt.xlabel("Значения")
    plt.ylabel("Частота")
    plt.show()
    
data:list = [1, 2, 2, 3, 2, 3, 2, 3, 0, 3, 1, 2, 3, 0, 1, 1, 0, 1, 3, 1, 2, 2, 4, 3, 3, 2, 0, 2, 1, 3, 3, 3, 0, 2, 1, 1, 1, 4, 2, 2, 3, 2, 1, 2, 4, 2,3,3,2,2]

#0,1,2,3,4
unique_digits:list = list(set(data))

sorted_data: list = variation(data=data)

# %% [markdown]
# ***Эмпирическая функция распределения:***
# $$F_n(x)=\left\{\begin{array}{l}0 \;при\;-\infty<x\leq0\\0,1 \;при\;0<x\leq1\\0,32 \;при\;1<x\leq2\\0,66 \;при.\;2<x\leq3\\0,94 \;при\;3<x\leq4\\1 \;при\;4<x\leq+\infty\end{array}\right.$$

# %%
empirical_function(sorted_data=sorted_data, unique_digits = unique_digits)

histogram(data = sorted_data, unique_digits = unique_digits)

# %% [markdown]
# #### b)Вычислить выборочные аналоги следующих числовых характеристик: (i) математического ожидания, (ii)дисперсии, (iii) СКО (iv) медианы, (v)ассиметрии, (vi) эксцесса, (vii)вероятности  P(𝑋∈[𝑎,𝑏])

# %%
from scipy.stats import skew,kurtosis
def numerical_characteristics(data:list)->None:
    """
    Функция для вывода характеристик для 2-го задания
    """
    #Мат.ожидание
    mean = np.mean(data)

    #Дисперсия 
    dispersion = np.var(data)
    
    #CКО
    std_deviation = np.std(data)
    
    #Медиана 
    median = np.median(data)
    
    #Ассиметрия 
    assymetric = skew(data)
    
    #Эксцесс
    excess = kurtosis(data)
    
    #Вероятность попадания P(X ∈ [a, b])
    a:float = 0.00
    b: float = 2.85
    possibility:float = sum(1 for digit in data if a<=digit<=b)/len(data)
    
    print(f"Выборочные характеристики:\n"
          f"Мат.ожидание:{mean},\n"
          f"Дисперсия: {dispersion},\n"
          f"СКО: {std_deviation},\n"
          f"Медиана: {median},\n"
          f"Ассиметрия: {assymetric},\n"
          f"Эксцесс: {excess}\n"
          f"Вероятность попадания P(X ∈ [{a}, {b}]): {possibility}\n")

numerical_characteristics(data = data)

# %% [markdown]
# ***Выборочные характеристики***
#
# Мат.ожидание:
# $$Ex=\overline x=\frac1{50}\left(0\times5+1\times11+2\times17+3\times14+4\times3\right)=1,98$$
# Дисперсия:
# $$DX=E\left(X-E\left(X\right)\right)^2=E\left(X^2\right)-\left(EX\right)^2=\frac1{50}\left(0\times5+1\times11+4\times17+9\times14+16\times3\right)-\left(1,98\right)^2\\=5,06-3,9024=1,1396$$
# СКО:
# $$s=\left(DX\right)^\frac12=\left(1,396\right)^\frac12=1,06752$$
# Медиана:
#
# $$np=50\times\frac12=25,\;то\;\lbrack x_{25};x_{26})=\frac{2+2}2=2\\z_{50,\frac12}=2$$
#
# Ассиметрия:
# $$\widehat{Skew}\left(x\right)=\frac{\frac1n\sum_{n=1}^n\left(x_i-\overline x\right)^3}{s^3}=\\=\frac{{\displaystyle\frac1{50}}\left(5\times\left(0-1,98\right)^3+11\times\left(1-1,98\right)^3+17\times\left(2-1,98\right)^3+14\times\left(3-1,98\right)^3+3\times\left(4-1,98\right)^3\right)}{\left(1.06752\right)^3}=\\=-0.157508$$
# Эксцесс:
# $$\widehat{Kurt}\left(x\right)=\frac{\frac1n\sum_{n=1}^n\left(x_i-\overline x\right)^4}{s^4}-3=\\=\frac{\displaystyle\frac1{50}\left(5\times\left(0-1,98\right)^4+11\times\left(1-1,98\right)^4+17\times\left(2-1,98\right)^4+14\times\left(3-1,98\right)^4+3\times\left(4-1,98\right)^4\right)}{\left(1.06752\right)^4}-3=\\=-0.65768$$
#
# Вероятность попадания:
# $$P\left(x\in\left[a,b\right]\right)=F\left(b\right)-F\left(a\right)=F\left(2,85\right)-F\left(0\right)=0,66-0=0,66$$

# %% [markdown]
# #### c)В предположении, что исходные наблюдения являются выборкой из распределения Пуассона, построить оценку максимального правдоподобия параметра  λ, а также оценку  λ  по методу моментов, найти смещение оценок.
#
# Плотность распределения:
#
# $p_\theta\left(x\right)=\frac{\lambda^x}{x!}e^{-\lambda}$
#
# Функция правоподобия:
#
# $L\left(\overrightarrow x,\theta\right)=\prod_{i=1}^n\frac{\lambda^x}{x!}e^{-\lambda}=e^{-n\lambda}\times\frac{\lambda^{{\displaystyle\sum_{i=1}^n}x_i}}{\prod_{i=1}^nx!}$
#
# $g(T)=e^{-n\lambda}\times{\lambda^{\sum_{i=1}^nx_i}}_i\;,\;h(\overrightarrow x)=\frac1{{\displaystyle\prod_{i=1}^n}x!}$
#
# МДС:
#
# $T=\left(\overset n{\underset{i=1}{\sum x_i}}\right)$
#
# ПДС:
#
# Т.к. данное распределение принадлежит к семейству экспоненциальных распределений, то ПДС
#
# ОМП:
#
# $LL\left(\overrightarrow x,\theta\right)=-n\lambda+\overset n{\underset{i=1}{\sum x_i}}\left(\ln\lambda\right)+\ln\left(\frac1{\prod_{i=1}^nx!}\right)$
#
# $\frac{\partial LL\left(\overrightarrow x,\theta\right)}{\partial\lambda}=-n+\frac{\displaystyle\overset n{\underset{i=1}{\sum x_i}}}\lambda+0$
# $\widehat\lambda=\frac{\displaystyle\overset n{\underset{i=1}{\sum x_i}}}n=\widehat x$
#
# $\widehat{\;\theta}=\lambda=\overline x\;-\;ОМП$
#
# Проверка на несмещенность:
#
# $E\widehat\theta=E\left(\frac{\displaystyle\overset n{\underset{i=1}{\sum x_i}}}n\right)=\frac1n\times E\left(\overset n{\underset{i=1}{\sum x_i}}\right)=\frac1n\times\overset n{\underset{i=1}{\sum E}}\left(x_i\right)=\frac1n\times n\lambda=\lambda\;-\;несмещенная\;оценка$
#
# $\widetilde\theta=\widehat\theta\$
#
# ОММ:
# $Т.к.\;1\;параметр,\;то:\\E(x_1)=\lambda\;-\;\;1-ый\;момент\;распределения\;Лапласа\\M(x_1)=\overline{x\;}\;=\frac{{\displaystyle\sum_{i=i}^n}x_i}n\\\\\\\widetilde\theta=\lambda=\overline x$

# %% [markdown]
# #### d)Построить асимптотичексий доверительный интервал уровня значимости  𝛼1 для параметра  𝜆 на базе оценки максимального правдоподобия
# Решение 2 способами:
# 1. Построение асимптотического доверительного интервала (Далее как А.Д.И.) на базе ОМП:
#
# $\widehat{\;\theta}=\lambda=\overline x$ - ОМП
#
# $\sqrt n\left(\widehat\theta\left(\overline x\right)-\theta\right)\sim\mathbb{N}\left(0,\frac1{I\left(\theta\right)}\right),\;где\;I\left(\theta\right)=\lim_{n\rightarrow\infty}\left(\frac{I_n\left(\theta\right)}n\right)\;и\;где\;I_n\left(\theta\right)\;-\;информация\;Фишера$
#
# Найдем информацию Фишера:
#
# $I_n\left(\theta\right)=-E\frac{\partial^2LL}{\partial\theta^2}$
#
# $\frac{\partial^2LL\left(\overrightarrow x,\lambda\right)}{\partial\lambda^2}=-\frac{\displaystyle\overset n{\underset{i=1}{\sum x_i}}}{\lambda^2}$
#
# $I_n\left(\lambda\right)=E\frac{\displaystyle\overset n{\underset{i=1}{\sum x_i}}}{\lambda^2}=\frac1{\lambda^2}E\overset n{\underset{i=1}{\sum x_i=}}\frac1{\lambda^2}\sum_{i=1}^nEx_i=\frac1{\lambda^2}n\lambda=\frac n\lambda$
#
# $I\left(\lambda\right)=\lim_{n\rightarrow\infty}\left(\frac{l_n\left(\lambda\right)}n\right)=\lim_{n\rightarrow\infty}\left(\frac1n\times\frac n\lambda\right)=\frac1\lambda\\Тогда\\\sqrt{nI\left(\lambda\right)}\left(\widehat\lambda\left(\overrightarrow x\right)-\lambda\right)\sim\mathbb{N}\left(0,1\right)\\\operatorname{𝑥}_\alpha:Ф\left(\operatorname{𝑥}_\alpha\right)=1-\frac\alpha2=1-\frac{0.01}2=0.995$
#
# Получим доверительный интервал:
# $\left[\widehat\theta\left(\overrightarrow x\right)-\frac{x_\alpha}{\sqrt{nl\left(\widehat\theta\right)}},\widehat\theta\left(\overrightarrow x\right)+\frac{x_\alpha}{\sqrt{nl\left(\widehat\theta\right)}}\right]\ni\theta\\\left[\overline x-\frac{x_\alpha}{\sqrt{n{\displaystyle\frac1{\overline x}}}},\overline x+\frac{x_\alpha}{\sqrt{n\frac1{\overline x}}}\right]\ni\lambda$
# $\\\left[1,98-\frac{2.575}{\sqrt{\displaystyle\frac{50}{1,98}}},1,98+\frac{2.575}{\sqrt{\frac{50}{1,98}}}\right]\ni\lambda\\1,467\leq\lambda\leq2,492$ - А.Д.И. уровня доверия $\alpha_1$ на базе ОМП

# %%
from scipy.stats import norm
from math import sqrt
def NormPffCalc(a:int)->float:
    """
    Для подсчета X(a)
    """
    X_a = norm.ppf(a)
    print(f"Значение X_a = {X_a}")
    return X_a
    

def Boarders(n:int, E:float,X_a:float):
    return f"граница: {E-(X_a/sqrt(n/E))}"
    

E:float = np.mean(data)
a1: float=0.01
r:float = 1-a1/2
X_a = NormPffCalc(a=r)
print(f"Левая {Boarders(n,E,X_a)}")
print(f"Правая {Boarders(n,E,-X_a)}")

# %% [markdown]
# 2.Построение А.Д.И. на базе асимптотической нормальной оценки параметра $\lambda$
# $\sqrt n\left(\widehat\theta\left(\overrightarrow x\right)-\theta\right)\sim\mathbb{N}\left(0,\sigma^2\left(\theta\right)\right)\;-\;асимптотическая\;нормальность\\Тогда\;\\\sqrt n\frac{\widehat\theta\left(\overrightarrow x\right)-\theta}{\sigma\widehat\theta\left(x\right)}\sim\mathbb{N}\left(0,1\right)\\\sqrt{50}\frac{\overline x-\lambda}\sim\mathbb{N}\left(0,1\right)\\Выбираем\;x_{\alpha_1}:Ф\left(\;x_{\alpha_1}\right)=1-\frac{0,01}2=0,995\\Доверительный\;интервал:\\\left[\overline x-\frac{x_{\alpha_1}\sqrt{\overline x}}{\sqrt n};\overline x+\frac{x_{\alpha_1}\sqrt{\overline x}}{\sqrt n}\right]\ni\lambda\\\left[1,98-\frac{2.575\sqrt{1.98}}{\sqrt{50}};1,98+\frac{2.575\sqrt{1.98}}{\sqrt{50}}\right]\ni\lambda\\1,467\leq\lambda\leq2,492$

# %%
from scipy.stats import norm
from math import sqrt
def NormPffCalc(a:int)->float:
    """
    Для подсчета X(a)
    """
    X_a = norm.ppf(a)
    print(f"Значение X_a = {X_a}")
    return X_a
    

def Boarders(E: float, n:int,X_a:float):
    return f"граница: {E-((X_a*sqrt(E))/sqrt(n))}"
    

a1: float=0.01
E: float = np.mean(data)
r:float = 1-a1/2
X_a = NormPffCalc(a=r)
print(f"Левая {Boarders(E,n,X_a)}")
print(f"Правая {Boarders(E,n,-X_a)}")

# %% [markdown]
# #### e)Используя гистограмму частот, построить критерий значимости  𝜒2 проверки простой гипотезы согласия с распределением Пуассона с параметром  𝜆0. Проверить гипотезу на уровне значимости  𝛼1. Вычислить наибольшее значение уровня значимости, на котором ещё нет оснований отвергнуть данную гипотезу.
# $P_\theta\left(x\right)=\frac{\lambda^x}{x!}e^{-\lambda}\;\;-\;распределение\;Пуассона,\;\lambda_0=2,00,\alpha_1=0,01\\P_{H_0}=\left(X\in I_i\right)=\sum_{k\in I_i}^n\frac{\lambda_0^k}{k!}e^{-\lambda_0},\;где\;I\;-\;интервалы\;\\n\;=\;50\\Группируем\;данные\;по\;интервалам\;так,\;чтобы\;было \;не\;менее\;5\;значений:\\I_1=(-\infty;0\rbrack,\;n_1=5\\P_1=\frac{\left(2,00\right)^0}{0!}e^{-2,00}=0,1353\\Ожидаемая\;частота:\\nP_1=6,76\\\\I_2=(0;1\rbrack,\;n_2=11\\P_2=\frac{\left(2,00\right)^1}{1!}e^{-2,00}=0,2706\\Ожидаемая\;частота:\\nP_2=13,53\\\\I_3=(1;2\rbrack,\;n_3=17\\P_3=\frac{\left(2,00\right)^2}{2!}e^{-2,00}=0,2706\\Ожидаемая\;частота:\\nP_3=13,53\\\\I_4=(2;3\rbrack,\;n_4=14\\I_5=(3;4\rbrack,\;n_5=3\\P_4=\frac{\left(2,00\right)^3}{3!}e^{-2,00}+\frac{\left(2,00\right)^4}{4!}e^{-2,00}=0,2706\\Ожидаемая\;частота:\\nP_4=13,53$
#
#
# $Критерий:\;\;\;\chi^2:\;\chi_{н}^2=\sum_{i=1}^4\frac{\left(n_i-nP_i\right)^2}{nP_i}=2,70793$
#
#
# $Квантиль\;распределения:\\\operatorname{𝜒}_{1-0,01,4-1}^2=\operatorname{𝜒}_{0.99,3}^2=11,3449\\\operatorname{𝜒}^2<\operatorname{𝜒}_{0.99,3}^2\;(2,70793<11,3449)\;-\;\;по\;критерию\;Пирсона\;гипотеза\;не\;отвергается$
#
# $Наибольшее\;значение\;уровня\;значимости\;\approx0.438$
#
# $Код\;для\;нахождения\;наибольшего\;значения\;критерия\;уровня\;значимости,\;на\;котором\;еще\;нет\;нет\;оснований\;отвергнуть\;гипотезу:$

# %%
from math import exp as exp
from math import factorial as factorial
from scipy.stats import chi2 
def CriteriaCalcWFuncs(m:float,r:int,Criteria:float)->None:
    """
    Подсчет критерия с помощью встроенных функций, а также наибольшее значение уровня значимости
    """
    print(
        f"Значение хи^2: {chi2.ppf(m,r)}",
        f"\nНаибольшее значение уровня значимости: {1-chi2.cdf(Criteria,r)}"
    )
    

def CriteriaCalc(Pi:list, In:list)->float:
    """
    Подсчет критерия
    """
    
    squared_diff_sum:float = 0
    Pi[-1]=[sum(Pi[-1])]
    In[-1] = [sum(In[-1])]
    for n_elements, nPi_res in zip(In, Pi):
        for element, nPi in zip(n_elements, nPi_res):
            squared_diff_sum += ((element - nPi)**2) / nPi
            print(f"ni = {element}, nPi = {nPi}:\n(ni-nPi)^2/nPi = {((element - nPi)**2) / nPi}\n")

    print("Критерий:",squared_diff_sum)
    return squared_diff_sum 

def nPiCalc(lambda_0:float,k:int,n:int)->list[float]:
    """
    Подсчет nPi для каждого промежутка
    """
    
    return [(((lambda_0)**k[_]/(factorial(k[_])))*exp(-lambda_0))*n for _ in range(len(k))]


#входные данные:
lambda_0:float =2.00
n: int = 50
a1: float = 0.01
m: float = 1-a1
l_intervals:list=[[0],[1],[2],[3,4]]
n_elements:list = [[5],[11],[17],[14,3]]
r:int = len(l_intervals)-1

nPi_res:list=[nPiCalc(lambda_0,cur_interval,n) for cur_interval in l_intervals]
Criteria:float = CriteriaCalc(nPi_res,n_elements)
CriteriaCalcWFuncs(m,r,Criteria)

# %% [markdown]
# #### f)Построить критерий значимости проверки χ2 сложной гипотезы согласия с распределением Пуассона. Проверить гипотезу на уровне значимости. Вычислить наибольшее значение уровня значимости, на котором еще нет оснований отвергнуть данную гипотезу.
#
# $P_\theta\left(x\right)=\frac{\lambda^x}{x!}\times e^{-\lambda}\;-\;распределение\;Пуассона,\;\alpha_1=0,01,\;n=50\\в\;качестве\;параметра\;\lambda\;берется\;ОМП:\\\lambda=\widehat\theta=\widehat\lambda=\overline x,\overline{\;x}=1,98\\P_{H_0}=\left(X\in I_i\right)=\sum_{k=i}^n\frac{\left(\overline x\right)^k}{k!}\times e^{-\overline x}\;,\;где\;I\;-\;\;интервалы\\Группировка\;данных\;по\;интервалам\;так,\;чтобы\;было \;не\;менее\;5\;значений:\\\;I_1=(-\infty;0\rbrack,\;n_1=5\\P_1=\frac{\left(1,98\right)^0}{0!}\times e^{-1,98}=0,1380\\Ожидаемая\;частота:\\nP_1=6,903$
#
# $I_2=(0;1\rbrack,\;n_2=11\\P_2=\frac{\left(1,98\right)^1}{1!}\times e^{-1,98}=0,2733\\Ожидаемая\;частота:\\nP_2=13,66$
#
# $I_3=(1;2\rbrack,\;n_3=17\\P_3=\frac{\left(1,98\right)^2}{2!}\times e^{-1,98}=0,2706\\Ожидаемая\;частота:\\nP_2=13,53$
#
# $I_4=(2;3\rbrack,\;n_4=14\\I_5=(3;4\rbrack,\;n_5=3\\P_4=\frac{\left(1,98\right)^3}{3!}\times e^{-1,98}+\frac{\left(1,98\right)^4}{4!}\times e^{-1,98}=0,2670\\Ожидаемая\;частота:\\nP_4=13,35$
#
# $Критерий:\operatorname{𝜒}^2:\operatorname{𝜒}_{н}^2=\sum_{i=1}^4\frac{\left(n_i-nP_i\right)^2}{nP_i}=2,55955\\\operatorname{𝜒}_{1-0.001,4-1}^2=\operatorname{𝜒}_{0.99,3}^2=11,3449\\\\\operatorname{𝜒}^2<\operatorname{𝜒}_{0.99,3}^2\left(2,55955<11,3449\right)\;-\;по\;критерию\;Пирсона\;гипотеза\;не\;отвергается$
#
#
# $Наибольшее\;значение\;уровня\;значимости\;\approx0.402$
# $Код\;для\;нахождения\;наибольшего\;значения\;критерия\;уровня\;значимости,\;на\;котором\;еще\;нет\;нет\;оснований\;отвергнуть\;гипотезу:$

# %%
#входные данные:
lambda_0:float =1.98
n: int = 50
a1: float = 0.01
m: float = 1-a1
l_intervals:list=[[0],[1],[2],[3,4]]
n_elements:list = [[5],[11],[17],[14,3]]
r:int = len(l_intervals)-1

nPi_res:list=[nPiCalc(lambda_0,cur_interval,n) for cur_interval in l_intervals]
Criteria:float = CriteriaCalc(nPi_res,n_elements)
CriteriaCalcWFuncs(m,r,Criteria)

# %% [markdown]
# #### g)Построить наиболее мощный критерий проверки простой гипотезы пуассоновости с параметром  𝜆=𝜆0 при альтернативе пуассоновости с параметром  𝜆=𝜆1. Проверить гипотезу на уровне значимости  𝛼1. Что получится, если поменять местами основную и альтернативную гипотезы?
# $L\left(\overrightarrow x,\lambda\right)=e^{-n\lambda}\times\frac{\lambda{\displaystyle\overset n{\underset{i=1}{\times\sum x_i}}}}{\displaystyle\prod_{i=1}^nx!}$
#
# $\lambda_0=2,00;\lambda_1=3,00;\alpha_1=0,01\\H_0=\lambda_0,\;H_1=\lambda_1\\\\Статистика\;отношения\;правоподобия:\\LR\left(X,\lambda_1,\lambda_0\right)=\frac{L\left(x;\lambda_1\right)}{L\left(x;\lambda_0\right)}=\frac{\lambda_1^{{\displaystyle\sum_{i=1}^{50}}x_i}e^{-n\lambda_1}}{\lambda_0^{\sum_{i=1}^{50}x_i}e^{-n\lambda_0}}=\left(\frac{\lambda_1}{\lambda_0}\right)^{\sum_{i=1}^{50}x_i}\times e^{-n\lambda_1+n\lambda_0}\\LR\left(X,\lambda_1,\lambda_0\right)>C\\МДС:\\T\left(X\right)=\left(\sum_{I=1}^{50}X\right)\\\\Запись\;критерия\;:\\\\Ф\left(x\right)=\left\{\begin{array}{l}1,\;LR\left(x\right)>C\\p,\;\;LR\left(x\right)=C\\0,\;\;LR\left(x\right)<C\end{array}\right.\\В\;силу\;монотонности\;статистики\;LR\left(X\right)\;относительно\;МДС:\\LR\left(X\right)>C\Leftrightarrow\overline x<C\ast\\LR\left(X\right)<C\Leftrightarrow\overline x>C\ast\\Запись\;критерия\;в\;терминах\;\overline X:\\\\Ф\left(x\right)=\left\{\begin{array}{l}1,\;\overline X<C\ast\\p,\;\;\overline X=C\ast\\0,\;\;\overline X>C\ast\end{array}\right.$
# Согласно центральной предельной теореме, получим следующее отношение:
# $\sqrt n\frac{\left(\widehat\lambda-\lambda_0\right)}{\sqrt{\lambda_0}}\sim\mathbb{N}\left(0,1\right),\;где\;\sqrt n\frac{\left(\widehat\lambda-\lambda_0\right)}{\sqrt{\lambda_0}}\;-\;центральная\;нормированная\;оценка$
#
# $т.к.\;\widehat\lambda=\overline x,\;то\\\sqrt n\frac{\left(\overline x-\lambda_0\right)}{\sqrt{\lambda_0}}\sim\mathbb{N}\left(0,1\right)$
#
# $т.к.\;\widehat\lambda=\overline x,\;то\\\mathbb{P}\left(\sqrt n\frac{\left(\overline x-\lambda_0\right)}{\lambda_0}>\sqrt n\frac{\left(c^\ast-\lambda_0\right)}{\sqrt{\lambda_0}}\right)=1-Ф\left(\sqrt n\frac{\left(c^\ast-\lambda_0\right)}{\sqrt{\lambda_0}}\right)=\alpha_1\\Ф\left(\sqrt n\frac{\left(c^\ast-\lambda_0\right)}{\sqrt{\lambda_0}}\right)=1-\alpha_1=0,99$ - уровень значимости
#
# $\\Ф\left(0,99\right)=2.326\\Выразим\;c^\ast:\\\sqrt n\frac{\left(c^\ast-\lambda_0\right)}{\sqrt{\lambda_0}}=2,326\\\sqrt{50}\frac{\left(c^\ast-2,00\right)}{\sqrt{2}}=2,326\\c^\ast=2,462\\т.к.\;\\\overline x<c^\ast\Leftrightarrow LR\left(X\right)>C\;-\;гипотеза\;H_0\;отвергается$
#
#
# $Меняем\;гипотезы\;местами:\\H_0=\lambda_1;H_1=\lambda_0\\Стастистика\;отношения\;правдоподбия:\\LR\left(X,\lambda_0,\lambda_1\right)=\;\frac{L\left(x;\lambda_0\right)}{L\left(X;\lambda_1\right)}=\left(\frac{\lambda_0}{\lambda_1}\right)^\overset{50}{\underset{i=1}{\sum x_i}}\times e^{-n\lambda_0+\lambda_1}\\LR\left(X,\lambda_0,\lambda_1\right)>C\Leftrightarrow\overline x<C\ast\\\sqrt n\frac{\left(\widehat\lambda-\lambda_1\right)}{\sqrt{\widehat\lambda}}\sim\mathbb{N}\left(0,1\right),\;\\\widehat\lambda=\overline x\\\sqrt n\frac{\left(\overline x-\lambda_1\right)}{\sqrt{\overline x}}\sim\mathbb{N}\left(0,1\right)\\\mathbb{P}\left(\sqrt n\frac{\left(\overline x-\lambda_1\right)}{\sqrt{\lambda_0}}>\sqrt n\frac{\left(c\ast-\lambda_1\right)}{\sqrt{\lambda_0}}\right)=1-Ф\left(\sqrt n\frac{\left(c\ast-\lambda_1\right)}{\sqrt{\lambda_0}}\right)=\alpha_1\\Ф\left(\sqrt n\frac{\left(c\ast-\lambda_1\right)}{\sqrt{\lambda_0}}\right)=1-\alpha_1=0,99\\Ф\left(0,99\right)=2,326\\Выразим\;с\ast:\\\sqrt n\frac{\left(c\ast-\lambda_1\right)}{\sqrt{\lambda_0}}=2,326\\\sqrt{50}\frac{\left(c\ast-3,00\right)}{\sqrt{3.00}}=2,326\\c\ast=3,462\\т.к.\\\overline x<c\ast\Leftrightarrow LR\left(X\right)>C\;-\;гипотеза\;отвергается$

# %% [markdown]
# #### h) Замена на семейство геометрических распределений
# $$\\{\mathbb{P}}_\lambda\left(X=k\right)=\frac{\lambda^k}{\left(\lambda+1\right)^{k+1}},k\in{\mathbb{Z}}_+$$
# #### h.c)
# $Плотность\;распределения:\\p_\lambda\left(k\right)=\frac{\lambda^k}{\left(\lambda+1\right)^{k+1}},k\in{\mathbb{Z}}_+\\Функция\;правдоподобия:\\L\left(\overrightarrow x,\lambda\right)=\prod_{i=1}^n\frac{\lambda^k}{\left(\lambda+1\right)^{k+1}}=\lambda^{\sum_{i=1}^nx_i}\times\frac1{\left(\lambda+1\right)^{\sum_{i=1}^nx_i+n}}\\g\left(T\right)=\lambda^{\sum_{i=1}^nx_i}\times\frac1{\left(\lambda+1\right)^{\sum_{i=1}^nx_i+n}},\;h\left(\overrightarrow x\right)=1\\МДС:\\T=\left(\sum_{i=1}^nx\right)\\ПДС:\\Т.к.\;данное\;распредеелние\;принадлежит\;к\;семейству\;экспоненциальных\;распределений,\;то\;ПДС\\\\LL\left(\overrightarrow x,\lambda\right)=\sum_{i=1}^nx_iln\left(\lambda\right)-\sum_{i=1}^nx_i\ln\left(\lambda+1\right)-n\ln\left(\lambda+1\right)\\\frac{\partial LL\left(\overrightarrow x,\lambda\right)}{\partial\lambda}=\frac{\sum_{i=1}^nx_i}\lambda-\frac{\sum_{i=1}^nx_i}{\lambda+1}-\frac n{\lambda+1}\\\frac{\sum_{i=1}^nx_i}\lambda-\frac{\sum_{i=1}^nx_i}{\lambda+1}-\frac n{\lambda+1}=0\\\sum_{i=1}^nx_i\left(\lambda+1\right)-\left(\lambda\right)\left(\sum_{i=1}^nx_i+n\right)=0\\\sum_{i=1}^nx_i\left(\lambda+1\right)=\left(\lambda\right)\left(\sum_{i=1}^nx_i+n\right)\\\lambda\sum_{i=1}^nx_i+\sum_{i=1}^nx_i=\lambda\sum_{i=1}^nx_i+n\lambda\\\sum_{i=1}^nx=n\lambda\\\widehat\lambda=\frac{\sum_{i=1}^nx}n\\\widehat\lambda=\overline x\\\widehat\theta=\widehat\lambda=\overline x\;-\;ОМП$
#
# $Проверка\;на\;несмещенность:\\E\widehat\theta=E\overline x=E\left(\frac{\displaystyle\overset n{\underset{i=1}{\sum x_i}}}n\right)=\frac1nE\left(\overset n{\underset{i=1}{\sum x_i}}\right)=\frac1n\sum_{i=1}^nEx_i=\frac1n\times n\lambda=\lambda-\;смещенная\;оценка\\\widetilde\theta=\widehat\theta\;-\;\;НРМД\;-оценка\\ОММ:\\Т.к.\;1\;параметр,\;то\;\\E\left(x_1\right)=\lambda\\M_1\;=\overline x=\frac{{\displaystyle\sum_{i=1}^n}x_i}n\\\widehat\lambda=\overline x=1,98$

# %% [markdown]
# ***h.d)***
# ***Построение двумя способами***
#
# Построение А.Д.И. на базе ОМП:
#
# $\widehat{\;\theta}=\lambda=\overline x$ - ОМП
#
# $\sqrt n\left(\widehat\theta\left(\overline x\right)-\theta\right)\sim\mathbb{N}\left(0,\frac1{I\left(\theta\right)}\right),\;где\;I\left(\theta\right)=\lim_{n\rightarrow\infty}\left(\frac{I_n\left(\theta\right)}n\right)\;и\;где\;I_n\left(\theta\right)\;-\;информация\;Фишера$
#
# Найдем информацию Фишера:
# $I_n\left(\theta\right)=-E\left(\frac{\partial^2LL\left(\overrightarrow x,\lambda\right)}{\partial\lambda^2}\right)\\\frac{\partial^2LL\left(\overrightarrow x,\lambda\right)}{\partial\lambda^2}=-\frac{{\displaystyle\sum_{I=1}^n}x_I}{\lambda^2}+\frac{\displaystyle\overset n{\underset{I=1}{n\sum}}x_I}{\left(\lambda+1\right)^2}$
#
# $I_n\left(\theta\right)=-E\left(\frac{\partial^2LL\left(\overrightarrow x,\lambda\right)}{\partial\lambda^2}\right)\\\frac{\partial^2LL\left(\overrightarrow x,\lambda\right)}{\partial\lambda^2}=-\frac{{\displaystyle\sum_{I=1}^n}x_I}{\lambda^2}+\frac{\displaystyle\sum_{I=1}^nx_I+n}{\left(\lambda+1\right)^2}\\I_n\left(\lambda\right)=-E\left(-\frac{\displaystyle\sum_{I=1}^nx_I}{\lambda^2}+\frac{\displaystyle\sum_{I=1}^nx_I+n}{\left(\lambda+1\right)^2}\right)=E\left(\frac{\displaystyle\sum_{I=1}^nx_I}{\lambda^2}\right)-E\left(\frac{\displaystyle\sum_{I=1}^nx_I}{\left(\lambda+1\right)^2}\right)=\frac{\sum_{I=1}^nEx_I}{\lambda^2}-\frac{\displaystyle\sum_{I=1}^nEx_I}{\left(\lambda+1\right)^2}-\frac{\displaystyle E\left(n\right)}{\left(\lambda+1\right)^2}\\=\frac n\lambda-\frac{n\lambda}{\left(\lambda+1\right)^2}-\frac n{\left(\lambda+1\right)^2}=\frac{n\left(\lambda+1\right)^2-n\lambda^2-n\lambda}{\lambda\left(\lambda+1\right)^2}=\frac{n\left(\lambda^2+2\lambda+1\right)-n\lambda^2-n\lambda}{\lambda\left(\lambda+1\right)^2}=\frac{n\lambda+n}{\lambda\left(\lambda+1\right)^2}=\frac{n\left(\lambda+1\right)}{\lambda\left(\lambda+1\right)^2}\\=\frac n{\lambda\left(\lambda+1\right)}$
#
# $\operatorname{𝐼}(\lambda)=\lim_{n\rightarrow\infty}\left(\frac{\operatorname{𝐼}_n(\lambda)}n\right)=\lim_{n\rightarrow\infty}\left(\frac{\displaystyle\frac n{\lambda\left(\lambda+1\right)}}n\right)=\lim_{n\rightarrow\infty}\left(\frac1{\lambda\left(\lambda+1\right)}\right)=\frac1{\lambda\left(\lambda+1\right)}$
#
# $Тогда:\\\sqrt{n\operatorname{𝐼}(\lambda)}\left(\widehat\lambda\left(\overrightarrow x\right)-\lambda\right)\sim\mathbb{N}\\\operatorname{𝑥}_\alpha:Ф\left(\alpha\right)=1-\frac\alpha2=1-\frac{\alpha_1}2=0,995\\Получим\;доверительный\;интервал:$
#
# $\left[\widehat\theta\left(\overrightarrow x\right)-\frac{x_\alpha}{\sqrt{nl\left(\widehat\theta\right)}},\widehat\theta\left(\overrightarrow x\right)+\frac{x_\alpha}{\sqrt{nl\left(\widehat\theta\right)}}\right]\ni\theta\\\left[\overline x-\frac{x_\alpha}{\sqrt{n\frac1{\overline x\left(\overline x+1\right)}}},\overline x+\frac{x_\alpha}{\sqrt{n\frac1{\overline x\left(\overline x+1\right)}}}\right]\ni\lambda\\\left[1,98-\frac{2.575}{\sqrt{50\frac1{1,98\left(1,98+1\right)}}},1,98+\frac{2.575}{\sqrt{50\frac1{1,98\left(1,98+1\right)}}}\right]\ni\lambda\\1,095\leq\lambda\leq2,864$

# %%
from scipy.stats import norm
from math import sqrt
def NormPffCalc(a:int)->float:
    """
    Для подсчета X(a)
    """
    X_a = norm.ppf(a)
    print(f"Значение X_a = {X_a}")
    return X_a
    

def Boarders(n:int, E:float,X_a:float):
    return f"граница: {E-(X_a*1/sqrt(n/(E*(E+1))))}"
    

E:float = np.mean(data)
print(E)
a1: float=0.01
r:float = 1-a1/2
print(r)
X_a = NormPffCalc(a=r)
#Для 1-ого способа
print(f"Левая {Boarders(n,E,X_a)}")
print(f"Правая {Boarders(n,E,-X_a)}")

# %% [markdown]
# #### h.e)
# $P_\lambda\left(X=k\right)=\frac{\lambda^k}{\left(\lambda+1\right)^{k+1}},\;\lambda_0=2,00,\alpha_1=0,01,\;I\;\\\\P_{H_0}=\left(X\in I_i\right)=\sum_{k\in I_i}^n\frac{\lambda^k}{\left(\lambda+1\right)^{k+1}},\;\;где\;I\;-\;интервалы\;\\n\;=\;50\\\\Группируем\;данные\;по\;интервалам:\\I_1=(-\infty;0\rbrack,\;n_1=5\\P_1=\frac{\left(2,00\right)^0}{\left(2,00+1\right)^{0+1}}=0,3333\\Ожидаемая\;частота:\\nP_1=16,6\\\\I_2=(0;1\rbrack,\;n_2=11\\P_2=\frac{\left(2,00\right)^1}{\left(2,00+1\right)^{1+1}}=0,2222\\Ожидаемая\;частота:\\nP_2=11,1\\\\I_3=(1;2\rbrack,\;n_3=17\\P_3=\frac{\left(2,00\right)^2}{\left(2,00+1\right)^{2+1}}=0,1481\\Ожидаемая\;частота:\\nP_3=7,4\\\\I_4=(2;3\rbrack,\;n_4=14\\I_5=(3;4\rbrack,\;n_5=3\\P_4=\frac{\left(2,00\right)^3}{3!}e^{-2,00}+\frac{\left(2,00\right)^4}{4!}e^{-2,00}=0,1646\\Ожидаемая\;частота:\\nP_4=8,2$
#
# $Критерий:\;\operatorname{𝜒}^2:\operatorname{𝜒}_{н}^2=\sum_{i=1}^4\frac{\left(n_i-nP_i\right)^2}{nP_i}=30\\\operatorname{𝜒}^2>\operatorname{𝜒}_{0.99,3}^2,\;по\;критерию\;Пирсона\;гипотеза\;отвергается$

# %%
from math import exp as exp
from math import factorial as factorial
from scipy.stats import chi2 
def CriteriaCalcWFuncs(m:float,r:int,Criteria:float)->None:
    """
    Подсчет критерия с помощью встроенных функций, а также наибольшее значение уровня значимости
    """
    print(
        f"Значение хи^2: {chi2.ppf(m,r)}",
        f"\nНаибольшее значение уровня значимости: {1-chi2.cdf(Criteria,r)}"
    )
    

def CriteriaCalc(Pi:list, In:list)->float:
    """
    Подсчет критерия
    """
    
    squared_diff_sum:float = 0
    Pi[-1]=[sum(Pi[-1])]
    In[-1] = [sum(In[-1])]
    for n_elements, nPi_res in zip(In, Pi):
        for element, nPi in zip(n_elements, nPi_res):
            squared_diff_sum += ((element - nPi)**2) / nPi
            print(f"ni = {element}, nPi = {nPi}:\n(ni-nPi)^2/nPi = {((element - nPi)**2) / nPi}\n")

    print("Критерий:",squared_diff_sum)
    return squared_diff_sum 

def nPiCalc(lambda_0:float,k:int,n:int)->list[float]:
    """
    Подсчет nPi для каждого промежутка
    """
    
    return [((lambda_0)**k[_])/((lambda_0 + 1)**(k[_] + 1)) * n for _ in range(len(k))]



#входные данные:
lambda_0:float =2.00
n: int = 50
a1: float = 0.01
m: float = 1-a1
l_intervals:list=[[0],[1],[2],[3,4]]
n_elements:list = [[5],[11],[17],[14,3]]
r:int = len(l_intervals)-1

nPi_res:list=[nPiCalc(lambda_0,cur_interval,n) for cur_interval in l_intervals]
Criteria:float = CriteriaCalc(nPi_res,n_elements)
CriteriaCalcWFuncs(m,r,Criteria)

# %% [markdown]
# #### h.f)
# $P_\lambda(x=k)=\frac\lambda{{(\lambda+1)}^{k+1}},\;a_1=0,01,\;n=50\\в\;качестве\;параметра\;\lambda\;берется\;ОМП:\\\lambda=\widehat\theta=\widehat\lambda=\overline x,\overline{\;x}=1,98\\P_\lambda(x\in I_i)=\sum_{k\in I_i}^n\frac{\lambda^k}{{(\lambda+1)}^{k+1}},\;где\;I\;-\;интервалы$
#
#
# $Группировка\;данных\;по\;интервалам:\\I_1=(-\infty;0\rbrack,\;n_1=5\\P_1=\frac{1,98^0}{\left(2,98\right)^{0+1}}=0,3357\\Ожидаемая\;частота:\\nP_1=16,778\\\\I_2=(0;1\rbrack,\;n_2=11\\P_2=\frac{1,98^1}{\left(2,98\right)^{1+1}}=0,2229\\Ожидаемая\;частота:\\nP_2=11,148\\\\I_3=(1;2\rbrack,\;n_3=17\\P_3=\frac{1,98^2}{\left(2,98\right)^{2+1}}=0,1481\\Ожидаемая\;частота:\\nP_3=7,407\\\\I_4=(2;3\rbrack,\;n_4=14\\I_5=(3;4\rbrack,\;n_5=3\\P_4=\frac{1,98^3}{\left(2,98\right)^{3+1}}+\frac{1,98^4}{\left(2,98\right)^{4+1}}=0,1638\\Ожидаемая\;частота:\\nP_3=8,19\\\\Критерий:\;\operatorname{𝜒}^2:\operatorname{𝜒}_{н}^2=\sum_{i=1}^4\frac{\left(n_i-nP_i\right)^2}{nP_i}=30,171\\\operatorname{𝜒}^2>\operatorname{𝜒}_{0.99,3}^2,\;по\;критерию\;Пирсона\;гипотеза\;отвергается$

# %%
from math import exp as exp
from math import factorial as factorial
from scipy.stats import chi2 
def CriteriaCalcWFuncs(m:float,r:int,Criteria:float)->None:
    """
    Подсчет критерия с помощью встроенных функций, а также наибольшее значение уровня значимости
    """
    print(
        f"Значение хи^2: {chi2.ppf(m,r)}",
        f"\nНаибольшее значение уровня значимости: {1-chi2.cdf(Criteria,r)}"
    )
    

def CriteriaCalc(Pi:list, In:list)->float:
    """
    Подсчет критерия
    """
    
    squared_diff_sum:float = 0
    Pi[-1]=[sum(Pi[-1])]
    In[-1] = [sum(In[-1])]
    for n_elements, nPi_res in zip(In, Pi):
        for element, nPi in zip(n_elements, nPi_res):
            squared_diff_sum += ((element - nPi)**2) / nPi
            print(f"ni = {element}, nPi = {nPi}:\n(ni-nPi)^2/nPi = {((element - nPi)**2) / nPi}\n")

    print("Критерий:",squared_diff_sum)
    return squared_diff_sum 

def nPiCalc(lambda_0:float,k:int,n:int)->list[float]:
    """
    Подсчет nPi для каждого промежутка
    """
    
    return [((lambda_0)**k[_])/((lambda_0 + 1)**(k[_] + 1)) * n for _ in range(len(k))]



#входные данные:
lambda_0:float =1.98
n: int = 50
a1: float = 0.01
m: float = 1-a1
l_intervals:list=[[0],[1],[2],[3,4]]
n_elements:list = [[5],[11],[17],[14,3]]
r:int = len(l_intervals)-1

nPi_res:list=[nPiCalc(lambda_0,cur_interval,n) for cur_interval in l_intervals]
Criteria:float = CriteriaCalc(nPi_res,n_elements)
CriteriaCalcWFuncs(m,r,Criteria)

# %% [markdown]
# ### Часть 2
# #### a) Построить вариационный ряд, эмпирическую функцию распределения, гистограмму и полигон частот с шагом  ℎ

# %%
import matplotlib.pyplot as plt
import numpy as np
def graphic_builder(x_values:list,y_values:list,title:str,x_title:str,y_title:str)->None:
    """
    функция для построения графика эмпирической функции
    """
    
    plt.step(x_values,y_values,where="post",color="r")
    plt.xlabel(x_title)
    plt.ylabel(y_title)
    plt.title(title)
    plt.show()

def variation(data:list)->list:
    """
    Построение вариационного ряда
    """
    sorted_data:list =sorted(data)
    print(f"Вариационный ряд: \n{sorted_data}\n")
    return sorted_data

def empirical_function(sorted_data:list)->None:
    """
    Построение эмпирической функции
    """
     #подсчет общего количества чисел
    n:int = len(sorted_data)
    y = np.arange(1, n + 1) / n
     
    #Наименование графика
    title="Эмпирическая функция распределения"
    x_title = "Значения"
    y_title = "Частота"

    graphic_builder(sorted_data,y,title,x_title,y_title)
    

    
data:list = [-9.03, 12.77, 1.04, -18.47, 11.06, -7.30, 8.52, 5.20, -7.63, 17.79, -1.91, -1.26, 15.10, 3.59, 7.56, 1.64, -7.70, 
           -1.60, 0.49, 13.46, -2.44, 9.43, -5.47, 9.84, -2.80, 4.80, 6.34, -10.26, 10.19, 12.86, -15.83, 5.23, 16.21, 
           5.18, 15.77, -4.10, -1.30, 11.29, -14.72, -2.19, -11.57, -8.38, 7.05, -15.38, 2.37, 10.03, 18.24, 13.86, 12.47, -21.15]

#шаг
h:int = 4
sorted_data: list = variation(data=data)

# %%
empirical_function(sorted_data)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_polygon_frequency(data:list, h=1)->None:
    """
    Для построения полигона частот
    """
    counts, bins = np.histogram(numbers, bins=np.arange(min(data), max(data) + h, h))
    mid_points = [(bins[i] + bins[i+1]) / 2 for i in range(len(bins)-1)]
    plt.plot(mid_points, counts, marker='o', linestyle='-', label='Полигон частот',color='r')
    plt.xlabel('Значения')
    plt.ylabel('Частота')
    plt.title('Полигон частот')
    plt.show()

def plot_histogram(data:list, h=1)->None:
    """
    Для построения Гистограммы
    """
    counts, bins = np.histogram(numbers, bins=np.arange(min(data), max(data) + h, h))
    print(bins)
    # Построение гистограммы
    plt.bar(bins[:-1], counts, width=h, align='edge', edgecolor='red',color="white")

    # Добавление подписей
    plt.title('Гистограмма распределения чисел')
    plt.xlabel('Интервалы')
    plt.ylabel('Числа в интервалах')
    


plot_polygon_frequency(data, h=4)
plot_histogram(data, h=4)

# %%
import matplotlib.pyplot as plt
import numpy as np

def Polygon__histogram(data, h)->None:
    """
    Для построения Гистограммы и Полигона частот на одном графике
    """
    
    bins = np.arange(min(data), max(data) + h, h)
    
    # Построение полигона частот
    counts, bins_edges, _ = plt.hist(data, bins=bins, density=False, alpha=0.75, edgecolor="r", color="w")
    
    # Вычисление середин интервалов
    mid_points = [(bins[i] + bins[i+1]) / 2 for i in range(len(bins)-1)]

    # Построение полигона частот
    plt.plot(mid_points, counts, marker='o', linestyle='-', label='Полигон частот', color='r')

    plt.xlabel('Значения')
    plt.ylabel('Частота')
    plt.title(f'Полигон частот и гистограмма с шагом {h}')
    plt.legend()
    plt.show()

    
Polygon__histogram(data, h=4)

# %% [markdown]
# #### b) Вычислить выборочные аналоги следующих числовых характеристик:

# %%
from scipy.stats import skew,kurtosis
def numerical_characteristics(data:list)->None:
    """
    Функция для вывода характеристик для 2-го задания 2 части
    """
    #Мат.ожидание
    mean = np.mean(data)

    #Дисперсия 
    dispersion = np.var(data)
    
    #CКО
    std_deviation = np.std(data)
    
    #Медиана 
    median = np.median(data)
    
    #Ассиметрия 
    assymetric = skew(data)
    
    #Эксцесс
    excess = kurtosis(data)
    
    #Вероятность попадания P(X ∈ [a, b])
    c:float = -8.00
    d: float = 10.00
    possibility:float = sum(1 for digit in data if c<=digit<=d)/len(data)
    
    print(f"Выборочные характеристики:\n"
          f"Мат.ожидание:{mean},\n"
          f"Дисперсия: {dispersion},\n"
          f"СКО: {std_deviation},\n"
          f"Медиана: {median},\n"
          f"Ассиметрия: {assymetric},\n"
          f"Эксцесс: {excess}\n"
          f"Вероятность попадания P(X ∈ [{c}, { d}]): {possibility}\n")

numerical_characteristics(data = data)

# %% [markdown]
# ##### c) В предположении, что исходные наблюдения являются выборкой из нормального распределения, построить оценку максимального правдоподобия параметров  (𝑎,𝜎2) и соответствующие оценки по методу моментов. Найти смещение оценок.
# $Плотность\;распределения:\\p_\theta\left(x\right)=\frac1{\sigma\sqrt{2\pi}}exp\left(-\frac{\left(x-\alpha\right)^2}{2\sigma^2}\right)\\Функция\;правдоподобия:\\L\left(\overrightarrow{x;}\theta\right)=\prod_{i=1}^n\frac1{\sigma\sqrt{2\pi}}exp\left(-\frac{\left(x-\alpha\right)^2}{2\sigma^2}\right)=\left(\frac1{\sigma\sqrt{2\pi}}\right)^nexp\left(-\frac{{\displaystyle\sum_{i=1}^n}\left(x_i-\alpha\right)^2}{2\sigma^2}\right)\\МДС:\\Т=\left(\sum_{i=1}^nx_i^2,\sum_{i=1}^nx_i\right)\\ПДС:\\Т.к.\;данное\;распределение\;принадлежит\;к\;семейству\;экспоненц.\;распред.,\;то\;ПДС$
# $ОМП:\\LL\left(\overrightarrow{x;}\theta\right)=\left(\frac1{\sigma\sqrt{2\pi}}\right)^nexp\left(-\frac{\displaystyle\sum_{i=1}^n\left(x_i-\alpha\right)^2}{2\sigma^2}\right)=-n\ln\;\left(\sigma\right)-\frac n2\ln2\pi-\frac{\displaystyle\sum_{i=1}^n\left(x_i-\alpha\right)^2}{2\sigma^2}$
#
# $ОМП:\\По\;параметру\;\alpha:\\\frac{\partial LL\left(\overrightarrow{x;}\alpha\right)}{\partial\alpha}=-\frac{\displaystyle\sum_{i=1}^nx_i-2\alpha\sum_{i=1}^nx_i+n\alpha^2}{2\sigma^2}=\frac{\sum_{i=1}^nx_i-n\alpha}{\sigma^2}\\\frac{\sum_{i=1}^nx_i-n\alpha}{\sigma^2}=0\\\sum_{i=1}^nx_i=n\alpha\rightarrow\widehat\alpha=\overline x\\По\;параметру\;\sigma:\\\frac{\partial LL\left(\overrightarrow{x;}\sigma\right)}{\partial\sigma}=-\frac n\sigma+\frac{\displaystyle\sum_{i=1}^n\left(x_i-\alpha\right)^2}{\sigma^3}\\-\frac n\sigma+\frac{\displaystyle\sum_{i=1}^n\left(x_i-\alpha\right)^2}{\sigma^3}=0\\\sigma^2n=\sum_{i=1}^n\left(x_i-\alpha\right)^2=\frac{\sum_{i=1}^n\left(x_i-\alpha\right)^2}n\\\widehat\sigma^2=\frac{\sum_{i=1}^n\left(x_i-\alpha\right)^2}n=S^2$
#
# $Проверка\;на\;несмещенность:\\Оценка\;параметра\;\alpha\\E\widehat\alpha=E\left(\frac{{\displaystyle\sum_{i=1}^n}x_i}n\right)=\frac{\displaystyle1}nE\left(\sum_{i=1}^nx_i\right)=\frac{\displaystyle1}nn\alpha=\alpha\;-\;оценка\;несмещенная\\\widetilde\theta=\widehat\alpha\;-\;НРМД\;оценка\\Оценка\;параметра\;\sigma:\\E\widehat\sigma=E\left(S^2\right)=E\left(\frac{{\displaystyle\sum_{i=1}^n}\left(x_i-\overline X\right)^2}n\right)=\begin{bmatrix}Y_i=x_i-Ex_i\\EY_i=0;DY_i=\sigma^2\end{bmatrix}=\\E\left(\frac{\displaystyle\sum_{i=1}^n\left(y_i-\overline Y\right)^2}n\right)=E\left(\overline Y^2\right)-E\left(\overline Y\right)^2\boxed=\\\begin{bmatrix}E\left(\overline Y^2\right)=E\left(\frac1n\sum_{i=1}^n\left({y^2}_i\right)\right)=\frac1n\sum_{i=1}^nE\left({y^2}_i\right)=\sigma^2\\E\left(\overline Y\right)^2=E\left(\frac1n\sum_{i=1}^n\left(y_i\right)\right)^2=\frac1{n^2}E\left(\frac1n\sum_{i=1}^n\left(y_i\right)\right)^2=\frac1{n^2}\sum_{i=1}^n\overset n{\underset{i=j}{\sum E}}\left(y_iy_j\right)\end{bmatrix}\\Двойная\;сумма:\\\begin{bmatrix}i=j:Ey^2\\i\neq j:E\left(y_i\right)+E\left(y_j\right)\end{bmatrix}=\begin{bmatrix}\sigma^2\\i\neq j:E\left(y_i\right)E\left(y_j\right)=0\end{bmatrix}\\Получим:\\\\=\frac1{n^2}\left(n\sigma^2+\left(n^2-n\right)\times0\right)=\frac1{n^2}n\sigma^2=\frac{\sigma^2}n\\\boxed=\sigma^2-\frac{\sigma^2}n=\frac1n\left(\sigma^2n-\sigma^2\right)=\frac1n\sigma^2\left(n-1\right)=S^2\;\\E\widetilde\sigma=\frac n{n-1}ES^2\;=\frac n{n-1}\times\frac1n\sigma^2\left(n-1\right)=\sigma^2\;-\;НРМД\;оценка$
#
# $ОММ:$
# $\widetilde\theta=\left(\widetilde\alpha,\widetilde{\sigma^2}\right)=\left(\overline x,S^2\right)$

# %% [markdown]
# #### d) Построить доверительные интервалы уровня значимости  𝛼2  для параметров  (𝑎,𝜎2).
# $\alpha_2=0,20,n=50\\\sqrt{n-1}\frac{\overline x-\alpha}{\sqrt{S^2}}\sim S_{n-1}\\\operatorname{𝑥}_{\alpha_2}:Ф({\operatorname{𝑥}_{\alpha_2}}_2)=1-\frac{\alpha_2}2=1-\frac{0,2}2=0,9\\P\left(-x_{\alpha_2}\leq\sqrt{n-1}\frac{\overline x-\alpha}S\leq x_{\alpha_2}\right)\\Получим\;доверительный\;интервал:\\\left[\overline x-\frac{x_{\alpha_2S}}{\sqrt{n-1}};\overline x+\frac{x_{\alpha_2S}}{\sqrt{n-1}}\right]\ni\alpha\\\left[1.98-\frac{1,28\times10,16}{\sqrt{50-1}};\overline x+\frac{1,28\times10,16}{\sqrt{50-1}}\right]\ni\alpha\\\left[0.122;3.83\right]\ni\alpha$
#
# $\alpha_2=0,20,n=50\\\frac{nS^2}{\sigma^2}\sim X_{n-1}^2\\\operatorname{𝑥}_{\alpha_1}:Ф(\operatorname{𝑥}_{\alpha_1})=\frac{\alpha_2}2=\frac{0,2}2;\operatorname{𝑥}_{\alpha_2}:Ф(\operatorname{𝑥}_{\alpha_2})==1-\frac{0,2}2=0,9\\P\left(-x_{\alpha_1}\leq\frac{nS^2}{\sigma^2}\leq x_{\alpha_2}\right)\approx1-\alpha\\P\left(\frac{-x_{\alpha_1}}{nS^2}\leq\frac1{\sigma^2}\leq\frac{x_{\alpha_2}}{nS^2}\right)\approx1-\alpha\\P\left(\frac{nS^2}{-x_{\alpha_1}}\leq\sigma^2\leq\frac{nS^2}{x_{\alpha_2}}\right)\approx1-\alpha\\Получим\;доверительный\;интервал:\\\left[\frac{nS^2}{x_{\alpha_2}};\frac{nS^2}{x_{\alpha_1}}\right]\ni\sigma^2\\\left[\frac{50\left(10,16\right)^2}{62.037};\frac{50\left(10,16\right)^2}{36.818}\right]\ni\sigma^2\\\left[x;y\right]\ni\sigma^2\\\left[83;143\right]\ni\sigma^2$

# %%
from scipy.stats import norm
from math import sqrt
def NormPffCalc(a:int)->float:
    """
    Для подсчета X(a)
    """
    print(a)
    X_a = norm.ppf(a)
    print(f"Значение X_a = {X_a}")
    return X_a
    

def Boarders(E: float, n:int, S:float,X_a:float):
    return f"граница: {E-((X_a*S)/sqrt(n))}"
    
def Boarders2(alpha1:float):
    print(chi2.ppf((alpha1 / 2), 49))
    print(chi2.ppf(1-(alpha1 / 2), 49))
    
S:float = np.std(data)
a1: float=0.2
E: float = np.mean(data)
r:float = 1-a1/2
X_a = NormPffCalc(a=r)
print(f"Левая {Boarders(E,n,S,X_a)}")
print(f"Правая {Boarders(E,n,S,-X_a)}")
Boarders2(a1)

# %% [markdown]
# #### e) использованием теоремы Колмогорова построить критерий значимости проверки простой гипотезы согласия с нормальным распределением с параметрами  (𝑎0,𝜎20).Проверить гипотезу на уровне значимости  𝛼2. Вычислить наибольшее значение уровня значимости, на котором ещё нет оснований отвергнуть данную гипотезу.
# $\alpha_0=35,\;\sigma_0^2=10,\alpha_2=0.20\\Теорема\;Колмогорова:\\\sqrt n\times D_n\Rightarrow K$

# %%
from scipy.stats import kstest,  norm,kstwobign
import numpy as np
from numpy import sqrt

def KolmogorovCriteria(data:list,cdf:any,n:int,alpha2:float)->None:
    ks_statistics,ks_p_value = kstest(data,cdf)

    kvantil:float = kstwobign.ppf(1-alpha2)
    temp:float = sqrt(n)*ks_statistics

    print(f"Cтатистика критерия Колмогорова: {temp}\n",
          f"Ks_p_value: {ks_p_value}\n"
          f"Квантиль: {kvantil}\n")
    if temp>kvantil:
        print("Гипотеза отвергается")
    else:
        print("Гипотеза не отвaергается")

def Cdf_func(data:list,alpha0:int,sigma0:int)->any:
    return norm.cdf(data,loc=alpha0,scale=sigma0)

alpha0:int = 35
sigma0_2:int = 10
alpha2:float = 0.20

sigma0:int = sqrt(sigma0_2)
    
My_cdf = Cdf_func(data,alpha0,sigma0_2)
KolmogorovCriteria(data,My_cdf,n,alpha2)

# %% [markdown]
# $наибольшее\;значение\;уровня\;значимости,\;на\;котором\;ещё\;нет\;оснований отвергнуть\;данную\;гипотезу\approx4.884981308350689e-15\approx0$

# %% [markdown]
# #### f  Используя гистограмму частот, построить критерии значимости  𝜒2 проверки простой гипотезы согласия с нормальным распределением с параметрами  (𝑎0,𝜎20). Проверить гипотезу на уровне значимости  𝛼2. Вычислить наибольшее значение уровня значимости, на котором ещё нет оснований отвергнуть данную гипотезу.

# %%
import numpy as np
from math import exp as exp
from math import factorial as factorial
from scipy.stats import chi2 
def nPiCalc(sigma0:float,alpha0:float,k:float,n:int)->list[float]:
    """
    Подсчет nPi для каждого промежутка
    """
    
    return [(((1 / ( np.sqrt(sigma0**1/2*2 * np.pi))) * np.exp(-((cur_k - alpha0) ** 2) / (2 * sigma0))))*n for cur_k in k]

def CriteriaCalcWFuncs(m:float,r:int,Criteria:float)->None:
    """
    Подсчет критерия с помощью встроенных функций, а также наибольшее значение уровня значимости
    """
    print(
        f"Значение хи^2: {chi2.ppf(m,r)}",
        f"\nНаибольшее значение уровня значимости: {1-chi2.cdf(Criteria,r)}"
    )
    

def CriteriaCalc(Pi:list, In:list)->float:
    """
    Подсчет критерия
    """
    squared_diff_sum:float = 0
    Pi[0] = [sum(Pi[0])]
    for n_elements, nPi_res in zip(In, Pi):
        for element, nPi in zip(n_elements, nPi_res):
            squared_diff_sum += ((element - nPi)**2) / nPi
            print(f"ni = {element}, nPi = {nPi}:\n(ni-nPi)^2/nPi = {((element - nPi)**2) / nPi}\n")

    print("Критерий:",squared_diff_sum)
    return squared_diff_sum 



#входные данные:
n: int = 50
a0: float = 35
a2: float = 0.20
sigma0: float = 100
m: float = 1-a2
l_intervals:list=[[-17.15,-13.15,-9.15],[-5.15],[-1.15],[6.25],[10.85],[14.85],[18.85]]
n_elements:list = [[7],[6],[8],[10],[7],[7],[5]]
r:int = len(l_intervals)-1

nPi_res:list=[nPiCalc(sigma0,a0,l_intervals[i],n) for i in range(len(l_intervals))]
Criteria:float = CriteriaCalc(nPi_res,n_elements)
CriteriaCalcWFuncs(m,r,Criteria)
print(f"Гипотеза отвергается,т.к. 310>8.55")

# %% [markdown]
# #### g)Построить критерий проверки значимости  𝜒2 сложной гипотезы согласия с нормальным распределением. Проверить гипотезу на уровне значимости  𝛼2. Вычислить наибольшее значение уровня значимости, на которос ещё нет оснований отвергнуть данную гипотезу.
# $P_{H_0}=\left(k\in I_i\right)=\sum_{k\in l}\frac1{\sqrt{2\pi\sigma^2}}exp\left(\frac{-\left(k-\alpha\right)^2}{2\sigma^2}\right),\;\alpha_2=0,20,\alpha=\overline x=1.98,\sigma^2=103,\\где\;I\;-\;интервалы\\Группируем\;данные\;по\;интервалам:\\{\;I}_1\;=\left[-21.15:-9.15\right],n_1=2,n_2=3,n_3=2\\P_1=0.0411\\Ожидаемая\;частота:\\nP_1=\;11.88\\\\{\;I}_2\;=(-9.15;-5.15\rbrack,\;\;n_2=6\\P_2=0.0307\\Ожидаемая\;частота:\\nP_2=1.535\\\\{\;I}_3\;=(-5.15;-1.15\rbrack,\;\;n_3=8\\P_3=0.0374\\Ожидаемая\;частота:\\nP_3=1.874\\\\{\;I}_4\;=(-1.15;6.85\rbrack,\;\;n_4=10\\P_4=0.0359\\Ожидаемая\;частота:\\nP_4=1.798\\\\{\;I}_5\;=(6.85;10.85\rbrack,\;\;n_5=7\\P_5=0.0268\\Ожидаемая\;частота:\\nP_5=1.815\\\\{\;I}_6\;=(10.85;14.85\rbrack,\;\;n_6=7\\P_6=0.0268\\Ожидаемая\;частота:\\nP_6=0.879\\\\{\;I}_7\;=(14.85;18.85\rbrack,\;\;n_7=5\\P_7=0.017\\Ожидаемая\;частота:\\nP_7=1.645\\\\Критерий:\operatorname{𝜒}^2:\operatorname{𝜒}_н^2=\sum_{i=1}^8\frac{\left(n_i-nP_i\right)^2}{nP_i}= 189.85\\{\operatorname{𝜒}^2}_{1-0,20,8-1}={\operatorname{𝜒}^2}_{0,8,7}=8.55\\\operatorname{𝜒}_н^2>{\operatorname{𝜒}^2}_{0,8,7}\;По\;критерию\;Пирсона\;Гипотеза\;отвергается$

# %%
import numpy as np
from math import exp as exp
from math import factorial as factorial
from scipy.stats import chi2 
def nPiCalc(sigma0:float,alpha0:float,k:float,n:int)->list[float]:
    """
    Подсчет nPi для каждого промежутка
    """
    
    return [(((1 / ( np.sqrt(sigma0*2 * np.pi))) * np.exp(-((cur_k - alpha0) ** 2) / (2 * sigma0))))*n for cur_k in k]

def CriteriaCalcWFuncs(m:float,r:int,Criteria:float)->None:
    """
    Подсчет критерия с помощью встроенных функций, а также наибольшее значение уровня значимости
    """
    print(
        f"Значение хи^2: {chi2.ppf(m,r)}",
        f"\nНаибольшее значение уровня значимости: {1-chi2.cdf(Criteria,r)}"
    )
    

def CriteriaCalc(Pi:list, In:list)->float:
    """
    Подсчет критерия
    """
    squared_diff_sum:float = 0
    Pi[0] = [sum(Pi[0])]
    for n_elements, nPi_res in zip(In, Pi):
        for element, nPi in zip(n_elements, nPi_res):
            squared_diff_sum += ((element - nPi)**2) / nPi
            print(f"ni = {element}, nPi = {nPi}:\n(ni-nPi)^2/nPi = {((element - nPi)**2) / nPi}\n")

    print("Критерий:",squared_diff_sum)
    return squared_diff_sum 



#входные данные:
n: int = 50
a0: float = 1.98
a2: float = 0.20
sigma0: float = 103
m: float = 1-a2
l_intervals:list=[[-17.15,-13.15,-9.15],[-5.15],[-1.15],[6.25],[10.85],[14.85],[18.85]]
n_elements:list = [[7],[6],[8],[10],[7],[7],[5]]
r:int = len(l_intervals)-1

nPi_res:list=[nPiCalc(sigma0,a0,l_intervals[i],n) for i in range(len(l_intervals))]
Criteria:float = CriteriaCalc(nPi_res,n_elements)
CriteriaCalcWFuncs(m,r,Criteria)

# %% [markdown]
# #### h) Построить наиболее мощный критерий проверки простой гипотезы о нормальности с параметром  (𝑎,𝜎2)=(𝑎0,𝜎^2_0) при альтернативе нормальности с параметром  (𝑎,𝜎2)=(𝑎1,𝜎21). Проверить гипотезу на уровне значимости. Что получится, если поменять местами основновную и альтернативную гипотезы?

# %% [markdown]
# $\frac12aP\left(\overrightarrow x,\theta\right)=\frac1{\sigma\sqrt{2\pi}}exp\left(-\frac{\left(x-\alpha\right)}{2\sigma^2}\right)\\L\left(\overrightarrow x,\theta\right)=\left(\frac1{\sigma\sqrt{2\pi}}\right)^nexp\left(-\frac{{\displaystyle\sum_{i=1}^n}\left(x_i-\alpha\right)^2}{2\sigma^2}\right)\\H_0=\left(\alpha_0,\sigma_0^2\right)\;-\;основная\;гипотеза\\\;H_1=\left(\alpha_1,\sigma_1^2\right)\;-\;альтернативная\;гипотеза\\\alpha_0=35.00,\sigma_0=10.00,\alpha_1=2.00,\sigma_1=10.0\\Статистика\;отношения\;правдоподобия:\\\\LR\left(\overrightarrow x,\theta_0,\theta_1\right)=\frac{L\left(\overrightarrow x,\theta_1\right)}{L\left(\overrightarrow x,\theta_0\right)}=\frac{\left(\frac1{\sigma_1\sqrt{2\pi}}\right)^nexp\left(-\frac{\textstyle\sum_{i=1}^n\left(x_i-\alpha_1\right)^2}{2\sigma_1^2}\right)}{\left(\frac1{\sigma_0\sqrt{2\pi}}\right)^nexp\left(-\frac{\textstyle\sum_{i=1}^n\left(x_i-\alpha_0\right)^2}{2\sigma_0^2}\right)}\\=\frac{\left(\sigma_1\right)^{-n}exp\left(-\frac{\textstyle\sum_{i=1}^nx_i^2-2\alpha_1\sum_{i=1}^nx_i+n\alpha_1^2}{2\sigma_1^2}\right)}{\left(\sigma_0\right)^{-n}exp\left(-\frac{\textstyle\sum_{i=1}^nx_i^2-2\alpha_0\sum_{i=1}^nx_i+\alpha_0^2}{2\sigma_0^2}\right)}==\left[т.к.\sigma_1=\;\sigma_0,\;то\;\sigma\right]\\\\=exp\left(-\frac{\displaystyle\sum\nolimits_{i=1}^nx_i^2-2\alpha_1\sum\nolimits_{i=1}^nx_i+n\alpha_1^2}{2\sigma^2}+\frac{\displaystyle\sum\nolimits_{i=1}^nx_i^2-2\alpha_0\sum\nolimits_{i=1}^nx_i+n\alpha_0^2}{2\sigma^2}\right)=\\=exp\left(\frac1{2\sigma^2}\left(-\sum\nolimits_{i=1}^nx_i^2+2\alpha_1\sum\nolimits_{i=1}^nx_i-n\alpha_1^2+\sum\nolimits_{i=1}^nx_i^2-2\alpha_0\sum\nolimits_{i=1}^nx_i+n\alpha_0^2\right)\right)=\\=exp\left(\frac1{2\sigma^2}\left(2\alpha_1\sum\nolimits_{i=1}^nx_i-2\alpha_0\sum\nolimits_{i=1}^nx_i-n\alpha_1^2+n\alpha_0^2\right)\right)=\\=exp\left(\frac{\sum_{i=1}^nx_i}{\sigma^2}\left(\alpha_1-\alpha_0\right)-\frac n{2\sigma^2}\left(\alpha_1^2-\alpha_0^2\right)\right)$
# $\mathrm{LR}\left(\overrightarrow{\mathrm X},{\mathrm\theta}_1,{\mathrm\theta}_0\right)>\mathrm C\\\mathrm{МДС}:\\\mathrm T=\left(\overset{\mathrm n}{\underset{\mathrm i=1}{\sum{\mathrm x}_{\mathrm i}}}\right)\\\mathrm В\;\mathrm{силу}\;\mathrm{монотонности}\;\mathrm{статистики}\;\mathrm{LR}(\mathrm X)\;\mathrm{относительно}\;\mathrm{МДС}:\\\mathrm{LR}\left(\overrightarrow{\mathrm X}\right)>\mathrm C\Leftrightarrow\overline{\mathrm X}<\mathrm C^\ast\\\mathrm{LR}\left(\overrightarrow{\mathrm X}\right)<\mathrm C\Leftrightarrow\overline{\mathrm X}>\mathrm C^\ast\\\mathrm{Запись}\;\mathrm{критерия}\;\mathrm в\;\mathrm{терминах}\;\overline{\mathrm X}:\\\mathrm Ф\left(\mathrm х\right)=\left\{\begin{array}{l}1,\;\overline{\mathrm X}<\mathrm C^\ast\\\mathrm p,\;\overline{\mathrm X}=\mathrm C^\ast\\0,\;\overline{\mathrm X}>\mathrm C^\ast\end{array}\right.\\\mathrm{Согласно}\;\mathrm{ЦПТ},\;\mathrm{получим}\;\mathrm{следующее}:\\\sqrt{\mathrm n}\frac{\left(\widehat{\mathrm\lambda}-35\right)}{\mathrm\sigma}\sim\mathbb{N}\left(0,1\right)\\\sqrt{50}\frac{\left(1.98-35\right)}{10}=-16.51\sqrt2\\\mathrm Ф\left(\mathrm c\ast\right)=1-\frac{{\mathrm\alpha}_1}2=1-\frac{0,2}2=0,9\\\mathrm c\ast:\mathrm Ф\left(0,9\right)=1.28\\-16.51\sqrt2\;<1.28\;-\;\mathrm{по}\;\mathrm{критерию}\;\mathrm{Пирсона}\;\mathrm{гипотезу}\;\mathrm{отвергаем}$
#
# $\mathrm{Меняем}\;\mathrm{гипотезы}.\\{\mathrm H}_0=\left({\mathrm\alpha}_1,\mathrm\sigma_1^2\right)\;-\;\mathrm{основная}\;\mathrm{гипотеза}\\{\mathrm H}_1=\left({\mathrm\alpha}_0,\mathrm\sigma_0^2\right)\;-\;\mathrm{альтернативная}\;\mathrm{гипотеза}\\\mathrm{Статистика}\;\mathrm{отношения}\;\mathrm{правдоподбия}:\\\mathrm{LR}\left(\overrightarrow{\mathrm x},{\mathrm\theta}_1,{\mathrm\theta}_0\right)=\frac{\mathrm L\left(\overrightarrow{\mathrm x},{\mathrm\theta}_0\right)}{\mathrm L\left(\overrightarrow{\mathrm x},{\mathrm\theta}_1\right)}=\exp\left(\frac{\displaystyle\sum_{\mathrm i=1}^{\mathrm n}{\mathrm x}_{\mathrm i}}{\mathrm\sigma^2}\left({\mathrm\alpha}_0-{\mathrm\alpha}_1\right)-\frac{\mathrm n}{2\mathrm\sigma^2}\left(\mathrm\alpha_1^2-\mathrm\alpha_0^2\right)\right)\\\mathrm{LR}\left(\overrightarrow{\mathrm X},{\mathrm\theta}_1,{\mathrm\theta}_0\right)>\mathrm C\\\mathrm{МДС}:\\\mathrm T=\left(\overset{\mathrm n}{\underset{\mathrm i=1}{\sum{\mathrm x}_{\mathrm i}}}\right)\\\mathrm В\;\mathrm{силу}\;\mathrm{монотонности}\;\mathrm{статистики}\;\mathrm{LR}(\mathrm X)\;\mathrm{относительно}\;\mathrm{МДС}:\\\mathrm{LR}\left(\overrightarrow{\mathrm X}\right)>\mathrm C\Leftrightarrow\overline{\mathrm X}<\mathrm C^\ast\\\mathrm{LR}\left(\overrightarrow{\mathrm X}\right)<\mathrm C\Leftrightarrow\overline{\mathrm X}>\mathrm C^\ast\\\mathrm{Запись}\;\mathrm{критерия}\;\mathrm в\;\mathrm{терминах}\;\overline{\mathrm X}:\\\mathrm Ф\left(\mathrm х\right)=\left\{\begin{array}{l}1,\;\overline{\mathrm X}<\mathrm C^\ast\\\mathrm p,\;\overline{\mathrm X}=\mathrm C^\ast\\0,\;\overline{\mathrm X}>\mathrm C^\ast\end{array}\right.\\\mathrm{Согласно}\;\mathrm{ЦПТ},\;\mathrm{получим}\;\mathrm{следующее}:\\\sqrt{\mathrm n}\frac{\left(\widehat{\mathrm\lambda}-35\right)}{\mathrm\sigma}\sim\mathbb{N}\left(0,1\right)\\\mathbb{P}\left(\sqrt{\mathrm n}\frac{\left(\overline x-\alpha_1\right)}{\mathrm\sigma}>\sqrt{\mathrm n}\frac{\left(c^\ast-\alpha_1\right)}{\mathrm\sigma}\right)=1-Ф\left(\sqrt{\mathrm n}\frac{\left(c^\ast-\alpha_1\right)}{\mathrm\sigma}\right)=\alpha_2\\Ф\left(\sqrt{\mathrm n}\frac{\left(c^\ast-\alpha_1\right)}{\mathrm\sigma}\right)=1-\alpha_2=1-\alpha_2=1-0.2=0.8\\Ф\left(0.8\right)=0.8416\\Выразим\;c^\ast:\\\sqrt{50}\frac{\left(c^\ast-35\right)}{10}=0.8416\\\mathrm c\ast=36\\\\\overline{x\;}<c\ast\;-\;\mathrm{по}\;\mathrm{критерию}\;\mathrm{Пирсона}\;\mathrm{гипотезу}\;\mathrm{отвергаем}$

# %%
from scipy.stats import norm
from math import sqrt
def NormPffCalc(a:int)->float:
    """
    Для подсчета X(a)
    """
    X_a = norm.ppf(a)
    print(f"Значение X_a = {X_a}")
    return X_a


r:float = 1-0.2
k:float = 1-0.2/2
X_a = NormPffCalc(a=r)
X_a = NormPffCalc(a=k)

# %% [markdown]
# #### В пунктах (c) - (g) заменить семейство нормальных распределенеий на двухпараметрическое семейство распределений Лапласа с плотностями
# $P_{\alpha,\sigma}\left(x\right)=\frac1{\sqrt2\sigma}exp\left(-\frac{\sqrt2}\sigma\left|x-\alpha\right|\right)$
# #### i.c)
# $P_{\alpha,\sigma}\left(x\right)=\frac1{\sqrt2\sigma}exp\left(-\frac{\sqrt2}\sigma\left|x-\alpha\right|\right)$
# $Функция\;правдоподобия:\\L\left(\overrightarrow x,\theta\right)=\prod_{i=1}^n\frac1{\sigma\sqrt2}exp\left(-\frac{\sqrt2}\sigma\left|x-\alpha\right|\right)=\left(\frac1{\sigma\sqrt2}\right)^nexp\left(-\frac{\sqrt2}\sigma\sum_{i=1}^n\left|x-\alpha\right|\right)\\LL\left(\overrightarrow x,\theta\right)=n\ln\left(\frac1{\sigma\sqrt2}\right)-\frac{\sqrt2}\sigma\sum_{i=1}^n\left|x_i-\alpha\right|=-n\ln\left(\sigma2\right)-\frac{\sqrt2}\sigma\sum_{i=1}^n\left|x_i-\alpha\right|\\ОМП\\1.\;Параметр\;\alpha\\\frac{\partial LL\left(\overrightarrow x,\theta\right)}{\partial\alpha}=-\frac{\sqrt2}\sigma\sum_{i=1}^nsign\left(x_i-\alpha\right)\\-\frac{\sqrt2}\sigma\sum_{i=1}^nsign\left(x_i-\alpha\right)=0\\\widehat\alpha=Z_{n,0.5}\\2.\;Параметр\;\sigma\\\frac{\partial LL\left(\overrightarrow x,\theta\right)}{\partial\sigma}=-\frac{n2}{\sigma2}+\frac{\sqrt2}{\sigma^2}\sum_{i=1}^n\left|x_i-\alpha\right|=-\frac n\sigma+\frac{\sqrt2}{\sigma^2}\sum_{i=1}^n\left|x_i-\alpha\right|\\-\frac n\sigma+\frac{\sqrt2}{\sigma^2}\sum_{i=1}^n\left|x_i-\alpha\right|=0\\\widehat\sigma=\frac1n\sqrt2\sum_{i=1}^n\left|x_i-\alpha\right|\\\widehat\sigma^2=\frac1{n^2}\times2\left(\sum_{i=1}^n\left|x_i-\alpha\right|\right)^2\\Проверка\;на\;несмещенность:\\Оценка\;\widehat\alpha:\\E\left(\widehat\theta\right)=E\;\widehat{\left(\alpha\right)}=E\left(Z_{n,0.5}\right)=Z_{n,0.5}=\alpha\;-\;НРМД\;оценка\\\widetilde\theta=\widehat\theta\\Оценка\;\widehat\sigma:\\E\left(\widehat\theta\right)=E\;\widehat{\left(\sigma\right)}^2=E\left(\frac1{n^2}\times2\left(\sum_{i=1}^n\left|x_i-\alpha\right|\right)^2\right)$
# $ОММ:\\\widetilde\theta=\left(\widetilde\alpha,\widetilde{\sigma^2}\right)$

# %% [markdown]
# #### i.d)
# $\alpha_2=0.2,\;n=50\;\;для\;параметров\;\alpha,\sigma\\Построение\;доверительного\;интервала\;для\;\alpha:\\\sqrt{n-1}\frac{\overline x-\alpha}S\sim S_{n-1}\\Квантили:\\x_{\alpha_2}:Ф\left(x_{\alpha_2}\right)=1-\frac{\alpha_2}2=0,9\\P\left(-x_{\alpha_2}\leq\sqrt{n-1}\frac{\overline x-\alpha}S\leq x_{\alpha_2}\right)=1-\alpha\\P\left(\overline{x-}\frac{x_{\alpha_2}S}{\sqrt{n-1}}\leq\alpha\leq\overline x+\frac{x_{\alpha_2}S}{\sqrt{n-1}}\right)=1-\alpha\\Получим\;доверительный\;интервал:\\\left[\overline x-\frac{x_{\alpha_2}S}{\sqrt{n-1}};\overline x+\frac{x_{\alpha_2}S}{\sqrt{n-1}}\right]\ni\theta\\\left[\overline x-\frac{x_{\alpha_2}S}{\sqrt{n-1}};\overline x+\frac{x_{\alpha_2}S}{\sqrt{n-1}}\right]\ni\alpha$
# $\alpha_2=0.2,\;n=50\;\;для\;параметров\;\alpha,\sigma\\Построение\;доверительного\;интервала\;для\;\sigma:\\\frac{nS^2}{\sigma^2}\sim X_{n-1}^2\\Квантили:\\x_{\alpha_1}:Ф\left(x_{\alpha_1}\right)=\frac{\alpha_2}2=0,1\\x_{\alpha_2}:Ф\left(x_{\alpha_2}\right)=1-\frac{\alpha_2}2=0,9\\P\left(x_{\alpha_1}\leq\frac{nS^2}{\sigma^2}\leq x_{\alpha_2}\right)=1-\alpha\\P\left(\frac{\overline{x_{\alpha_1}}}{nS^2}\leq\frac1{\sigma^2}\leq\frac{\overline{x_{\alpha2}}}{nS^2}\right)=1-\alpha\\P\left(\frac{nS^2\overline{x_{\alpha_1}}}{\overline{x_{\alpha_2}}}\leq\sigma^2\leq\frac{nS^2}{\overline{x_{\alpha1}}nS^2}\right)=1-\alpha\\Получим\;доверительный\;интервал:\\\left[\frac{nS^2}{\overline{x_{\alpha_2}}};\frac{nS^2}{\overline{x_{\alpha1}}nS^2}\right]\ni\theta\\\left[\frac{nS^2}{\overline{x_{\alpha_2}}};\frac{nS^2}{\overline{x_{\alpha1}}nS^2}\right]\ni\sigma^2$

# %% [markdown]
# **i.e**

# %%
import numpy as np
from scipy.stats import kstest, kstwobign, laplace
from math import sqrt

def KolmogorovCriteria(data: list, cdf: any, alpha2: float) -> None:
    n = len(data)
    ks_statistics, ks_p_value = kstest(data, cdf)

    kvantil = kstwobign.ppf(1 - alpha2)
    temp = sqrt(n) * ks_statistics

    print(f"Статистика критерия Колмогорова: {temp}\n",
          f"Ks_p_value: {ks_p_value}\n"
          f"Квантиль: {kvantil}\n")

    if temp > kvantil:
        print("Гипотеза отвергается")
    else:
        print("Гипотеза не отвергается")

def Cdf_func(data: list, alpha0: int, sigma0_2: int) -> any:
    sigma0 = sqrt(2) / sqrt(sigma0_2)
    return laplace.cdf(data, loc=alpha0, scale=sigma0)

alpha0 = 35
sigma0_2 = 10
alpha2 = 0.20
print(data)

My_cdf = Cdf_func(data, alpha0, sigma0_2)
KolmogorovCriteria(data, My_cdf, alpha2)

# %% [markdown]
# **i.f)**
# $P_{H_0}=\left(k\in I_i\right)=\sum_{k\in I}\frac1{\sqrt{2\sigma^2}}exp\left(-\frac{\sqrt2}{\sigma_0}\left|k-\alpha\right|\right),\;\alpha=35,\;\alpha_2=0.2,\sigma_0=10.00,\;\\где\;I\;-\;интервалы\\\\Группируем\;данные\;по\;интервалам\;так,\;чтобы\;было\;не\;менее\;5\;элементов:\\I_1\;=\;(-21.15;-9.15\rbrack,\;n_1=7\\P_1=\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|-17.15-35\right|\right)+\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|-13.15-35\right|\right)+\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|-9.15-35\right|\right)=\\=0.0000259\\Ожидаемая\;частота:\\nP_1=0.001295\\\\I_2\;=\;(-9.15;-5.15\rbrack,\;n_2=6\\P_2=\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|-5.15-35\right|\right)=0.00024\\Ожидаемая\;частота:\\nP_2=0.012\\\\I_3\;=\;(-5.15;-1.15\rbrack,\;n_3=8\\P_3=\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|-1.15-35\right|\right)=0.0004\\Ожидаемая\;частота:\\nP_3=0.021\\\\I_4\;=\;(-1.15;6.85\rbrack,\;n_4=10\\P_4=\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|2.85-35\right|\right)+\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|6.85-35\right|\right)=0.0026\\Ожидаемая\;частота:\\nP_4=0.13\\\\I_5\;=\;(6.85;10.85\rbrack,\;n_5=7\\P_5=\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|10.85-35\right|\right)=0.0023\\Ожидаемая\;частота:\\nP_5=0.115\\\\I_6\;=\;(10.85;14.85\rbrack,\;n_6=7\\P_6=\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|14.85-35\right|\right)=0.0041\\Ожидаемая\;частота:\\nP_6=0.204\\\\I_7\;=\;(14.85;18.85\rbrack,\;n_7=5\\P_7=\frac1{10\sqrt2}exp\left(-\frac{\sqrt2}{10}\left|18.85-35\right|\right)=0.0072\\Ожидаемая\;частота:\\nP_7=0.360\\Критерий\;\operatorname{𝜒}^2:{\operatorname{𝜒}^2}_н=\sum_{i=1}^7\frac{\left(n_i-nP_i\right)^2}{nP_i}=45291.258\\\;\operatorname{𝜒}_{1-0.2,7-1}^2=\operatorname{𝜒}_{0.8,6}^2=4.64\\т.к.\;\\{\operatorname{𝜒}^2}_н>\operatorname{𝜒}_{0.8,6}^2,\;то\;гипотезу\;по\;критерию\;Пирсона\;отвергаем$
# $Наибольшее\;значение\;уровня\;значимости,\;при\;котором\;нет\;еще\;оснований\;отвергнуть\;данную\;гипотезу\;=\;0$

# %% [markdown]
# **i.g)**
# $P_{H_0}=\left(k\in I_i\right)=\sum_{k\in I}\frac1{\sqrt{2\sigma^2}}exp\left(-\frac{\sqrt2}\sigma\left|k-\alpha\right|\right),\;\alpha=\overline x=1.98,\;\alpha_2=0.2,\sigma^2=103,\;\sigma=\sqrt{103}\\где\;I\;-\;интервалы\\\\Группируем\;данные\;по\;интервалам\;так,\;чтобы\;было\;не\;менее\;5\;элементов:\\I_1\;=\;(-21.15;-9.15\rbrack,\;n_1=7\\P_1=\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|-17.15-1.98\right|\right)+\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|-13.15-1.98\right|\right)+\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|-9.15-1.98\right|\right)=\\=0.02808\\Ожидаемая\;частота:\\nP_1=14.14\\\\I_2\;=\;(-9.15;-5.15\rbrack,\;n_2=6\\P_2=\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|-5.15-1.98\right|\right)=0.025\\Ожидаемая\;частота:\\nP_2=1.28\\\\I_3\;=\;(-5.15;-1.15\rbrack,\;n_3=8\\P_3=\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|-1.15-1.98\right|\right)=0.04\\Ожидаемая\;частота:\\nP_3=2.25\\\\I_4\;=\;(-1.15;6.85\rbrack,\;n_4=10\\P_4=\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|2.85-1.98\right|\right)+\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|6.85-1.98\right|\right)=0.097\\Ожидаемая\;частота:\\nP_4=4.85\\\\I_5\;=\;(6.85;10.85\rbrack,\;n_5=7\\P_5=\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|10.85-1.98\right|\right)=0.0202\\Ожидаемая\;частота:\\nP_5=1.01\\\\I_6\;=\;(10.85;14.85\rbrack,\;n_6=7\\P_6=\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|14.85-1.98\right|\right)=0.0115\\Ожидаемая\;частота:\\nP_6=0.57\\\\I_7\;=\;(14.85;18.85\rbrack,\;n_7=5\\P_7=\frac1{\sqrt{2\times103}}exp\left(-\frac{\sqrt2}{\sqrt{103}}\left|18.85-1.98\right|\right)=0.0066\\Ожидаемая\;частота:\\nP_7=0.33\\Критерий\;\operatorname{𝜒}^2:{\operatorname{𝜒}^2}_н=\sum_{i=1}^7\frac{\left(n_i-nP_i\right)^2}{nP_i}=215.320\\\;\operatorname{𝜒}_{1-0.2,7-1}^2=\operatorname{𝜒}_{0.8,6}^2=4.64\\т.к.\;\\{\operatorname{𝜒}^2}_н>\operatorname{𝜒}_{0.8,6}^2,\;то\;гипотезу\;по\;критерию\;Пирсона\;отвергаем$
#
# $Наибольшее\;значение\;уровня\;значимости=\;0$

# %% [markdown]
# ## Выводы
#
#
#
# В результате проделанной работы был сформирован навык по реализации методов с помощью прикладных пакето. Была изученая теория по построению гипотез, а также методы программного языка Python для выполнения поставленных задач. Для имеющихся выборок были вычислены числовые характеристики, такие как мат.ожидание, дисперсия, СКО, медиана, асимметрия. Была построена ОММ и ОМП, доверительный интервал, критерии уровней значимости.
#
# Больше всего затруднений возникало с пониманием гипотез, в частности, сложной.
